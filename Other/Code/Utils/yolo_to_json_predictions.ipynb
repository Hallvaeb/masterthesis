# %% [markdown]
# Predictions are in yolo format:
#
# 0 0.727788 0.340503 0.0609681 0.258929
#
# and should be on label studio format:
#
# [{
# 	"data": {
# 	"image": "/data/upload/1/7f1bf9ff-060324-163034-70-temp51.jpg"
# 	},
# 	"predictions": [{
# 		"model_version": "one",
# 		"score": 0.5,
# 		"result": [
# 		{"id": "result1",
# 		"type": "rectanglelabels",
# 		"from_name": "label", "to_name": "image",
# 		"original_width": 600, "original_height": 403,
# 		"image_rotation": 0,
# 		"value": {
# 			"rotation": 0,
# 			"x": 4.98, "y": 12.82,
# 			"width": 32.52, "height": 44.91,
# 			"rectanglelabels": ["Person"]
# 			}
# 		},
# 		{"id": "result2",
# 		"type": "rectanglelabels",
# 		"from_name": "label", "to_name": "image",
# 		"original_width": 600, "original_height": 403,
# 		"image_rotation": 0,
# 		"value": {
# 			"rotation": 0,
# 			"x": 75.47, "y": 82.33,
# 			"width": 5.74, "height": 7.40,
# 			"rectanglelabels": ["Person"]
# 			}
# 		}]
# 	}]
# }]

# %%
import pandas as pd
import cv2
import os

# %%
# Path to the raw images, without any bounding boxes of processing
images_source_path = "/home/hallvaeb/data-masteroppgave/FIMUS-3rd-hm12/images"
# Where are the labels that are to be converted to json for label studio import?
labels_source_path = "/home/hallvaeb/data-masteroppgave/FIMUS-3rd-hm12/labels"
# This path is so that label studio can find the images when the predictions are imported. The rest of the path after the database-path opened up for label studio to see.
relative_images_path_for_labels_output				 = "FIMUS-3rd-hm12/images"
# Where to save the json file.
output_json        = '/home/hallvaeb/data-masteroppgave/FIMUS-3rd-hm12/yolo_inferences.json'

# %%
def read_yolo_file(file_path, image_id):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    data = []
    for line in lines:
        class_id, x_center, y_center, width, height, conf = line.split()
        data.append([image_id, float(class_id), float(x_center), float(y_center), float(width), float(height), float(conf)])
    df = pd.DataFrame(data, columns=['image_id', 'class_id', 'x_center_norm', 'y_center_norm', 'width_norm', 'height_norm', 'conf'])
    return df

# %%
def read_all_yolo_files(labels_source_path):
    all_detections = []
    for file_name in os.listdir(labels_source_path):
        if file_name.endswith('.txt'):
            image_id = os.path.splitext(file_name)[0]
            file_path = os.path.join(labels_source_path, file_name)
            df_detections = read_yolo_file(file_path, image_id)
            all_detections.append(df_detections)
    df_all_detections = pd.concat(all_detections, ignore_index=True)
    return df_all_detections

# %%
df_detections = read_all_yolo_files(labels_source_path)

# %%
df_detections.head()
# Out:
#                                             image_id  class_id  x_center_norm  \
# 0  130524-145947-hm12-awb1.5_1.5_br55_co0_ec0_iso...       0.0       0.475490
# 1  130524-152214-hm12-awb1.5_1.5_br55_co0_ec0_iso...       0.0       0.608456
# 2  130524-153536-hm12-awb1.5_1.5_br55_co0_ec0_iso...       0.0       0.981005
# 3  130524-151700-hm12-awb1.5_1.5_br55_co0_ec0_iso...       0.0       0.931373
# 4  130524-144821-hm12-awb1.5_1.5_br55_co0_ec0_iso...       0.0       0.840533
#
#    y_center_norm  width_norm  height_norm      conf
# 0       0.898133    0.143382     0.198052  0.898047
# 1       0.457995    0.036765     0.183036  0.764415
# 2       0.416802    0.037378     0.145292  0.644232
# 3       0.409294    0.049020     0.134334  0.745881
# 4       0.414976    0.065257     0.115666  0.725069

# %%
df_detections.describe()
# Out:
#        class_id  x_center_norm  y_center_norm  width_norm  height_norm  \
# count     242.0     242.000000     242.000000  242.000000   242.000000
# mean        0.0       0.663056       0.498129    0.064569     0.183312
# std         0.0       0.172193       0.089538    0.025128     0.078465
# min         0.0       0.235141       0.361201    0.016238     0.073458
# 25%         0.0       0.568091       0.433695    0.047794     0.125914
# 50%         0.0       0.643612       0.465198    0.055913     0.173092
# 75%         0.0       0.827781       0.559152    0.073759     0.226359
# max         0.0       0.991575       0.898133    0.143382     0.478896
#
#              conf
# count  242.000000
# mean     0.804984
# std      0.083597
# min      0.501905
# 25%      0.764869
# 50%      0.830221
# 75%      0.862698
# max      0.926271

# %%
# All images have the same resolution
def df_image_shapes_same_resolutions(folder_path):
	df = pd.DataFrame(columns=['image_id', 'image_width', 'image_height'])
	df.image_id = os.listdir(folder_path)
	shape = cv2.imread(os.path.join(folder_path, df.image_id[0])).shape
	df.image_height = shape[0]
	df.image_width = shape[1]
	df.image_id = df.image_id.str.replace('.jpg', '')
	return df

# %%
df_image_shapes = df_image_shapes_same_resolutions(images_source_path)

# %%
df = pd.merge(df_detections, df_image_shapes, on='image_id', how='inner')

# %%
def norm_center_to_denorm_x1y1(df):
	df['x1_denorm'] = (df['x_center_norm'].astype(float) - df['width_norm'].astype(float)/2) * 100
	df['y1_denorm'] = (df['y_center_norm'].astype(float) - df['height_norm'].astype(float)/2) * 100 
	df['w_denormalized'] = df['width_norm'].astype(float) * 100
	df['h_denormalized'] = df['height_norm'].astype(float) * 100

    # Drop now irrelevant columns, and move image shape to last columns
	to_drop= ['class_id', 'x_center_norm','y_center_norm','width_norm','height_norm', 'conf']
	df.drop(to_drop, axis=1, inplace=True)
	
	return df

# %%
df_detections_denorm = norm_center_to_denorm_x1y1(df)

# %%
df_detections_denorm.describe()
# Out:
#        image_width  image_height   x1_denorm   y1_denorm  w_denormalized  \
# count        242.0         242.0  242.000000  242.000000      242.000000
# mean        3264.0        2464.0   63.077172   40.647307        6.456865
# std            0.0           0.0   17.443208    5.971473        2.512808
# min         3264.0        2464.0   19.178930   28.571400        1.623770
# 25%         3264.0        2464.0   53.125009   36.688300        4.779410
# 50%         3264.0        2464.0   61.335823   39.955362        5.591300
# 75%         3264.0        2464.0   79.113025   43.597809        7.375920
# max         3264.0        2464.0   98.345615   79.910700       14.338200
#
#        h_denormalized
# count      242.000000
# mean        18.331244
# std          7.846542
# min          7.345780
# 25%         12.591350
# 50%         17.309250
# 75%         22.635950
# max         47.889600

# %%
def to_json(df):
    grouped = {}
    for d in df.values:
        key = d[0]
        prediction = {
            "model_version": "yolov9_1",
            "result": [{
                "value": {
                    "rotation": 0,
                    "x": round(d[3], 2),
                    "y": round(d[4], 2),
                    "width": round(d[5], 2),
                    "height": round(d[6], 2),
                    "rectanglelabels": ["Person"]
                },
                "id": "result1",
                "from_name": "label",
                "to_name": "image",
                "type": "rectanglelabels",
                "original_width": d[1],
                "original_height": d[2],
                "image_rotation": 0
            }]
        }
        if key not in grouped:
            grouped[key] = {
                "data": {
                    "filename": str(d[0]),
                    "image": f"/data/local-files/?d={relative_images_path_for_labels_output}/{d[0]}.jpg"
                },
                "predictions": []
            }
        grouped[key]["predictions"].append(prediction)

    # Convert the dictionary back to a list
    result = list(grouped.values())
    return result

# %%
res = to_json(df_detections_denorm)

# %%
res
# Out:
# [{'data': {'filename': '130524-145947-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145947-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 40.38,
#        'y': 79.91,
#        'width': 14.34,
#        'height': 19.81,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152214-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152214-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 59.01,
#        'y': 36.65,
#        'width': 3.68,
#        'height': 18.3,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153536-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153536-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 96.23,
#        'y': 34.42,
#        'width': 3.74,
#        'height': 14.53,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151700-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151700-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 90.69,
#        'y': 34.21,
#        'width': 4.9,
#        'height': 13.43,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144821-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144821-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 80.79,
#        'y': 35.71,
#        'width': 6.53,
#        'height': 11.57,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145638-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145638-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 38.48,
#        'y': 42.21,
#        'width': 5.85,
#        'height': 21.23,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144801-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144801-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 69.15,
#        'y': 33.93,
#        'width': 3.68,
#        'height': 15.87,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151742-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151742-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 33.98,
#        'y': 43.63,
#        'width': 6.46,
#        'height': 21.71,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155934-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155934-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 93.72,
#        'y': 33.73,
#        'width': 4.6,
#        'height': 14.33,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151838-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151838-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 68.38,
#        'y': 37.3,
#        'width': 5.36,
#        'height': 12.58,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-150001-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-150001-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 58.61,
#        'y': 49.15,
#        'width': 11.58,
#        'height': 38.88,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155824-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155824-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 82.63,
#        'y': 35.35,
#        'width': 5.39,
#        'height': 11.77,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 52.42,
#        'y': 46.88,
#        'width': 8.67,
#        'height': 24.19,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155523-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155523-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 66.51,
#        'y': 36.57,
#        'width': 4.32,
#        'height': 13.51,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152200-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152200-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 57.26,
#        'y': 37.09,
#        'width': 4.78,
#        'height': 18.47,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155749-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155749-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 62.9,
#        'y': 43.38,
#        'width': 7.17,
#        'height': 9.17,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 82.14,
#        'y': 39.98,
#        'width': 5.61,
#        'height': 7.43,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144740-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144740-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 55.24,
#        'y': 38.03,
#        'width': 4.44,
#        'height': 20.7,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-160413-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-160413-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 62.44,
#        'y': 40.38,
#        'width': 5.79,
#        'height': 12.58,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 52.02,
#        'y': 49.03,
#        'width': 11.12,
#        'height': 25.0,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144815-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144815-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 68.69,
#        'y': 34.09,
#        'width': 3.77,
#        'height': 15.83,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155817-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155817-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 85.66,
#        'y': 34.5,
#        'width': 5.48,
#        'height': 12.5,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 51.96,
#        'y': 47.77,
#        'width': 9.16,
#        'height': 23.74,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143856-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143856-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 56.4,
#        'y': 41.48,
#        'width': 5.7,
#        'height': 24.27,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155200-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155200-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 89.0,
#        'y': 34.13,
#        'width': 7.02,
#        'height': 13.64,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153714-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153714-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 80.06,
#        'y': 40.18,
#        'width': 5.42,
#        'height': 7.55,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151803-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151803-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 57.35,
#        'y': 43.14,
#        'width': 4.75,
#        'height': 22.81,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-150515-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-150515-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 85.91,
#        'y': 28.57,
#        'width': 4.53,
#        'height': 15.1,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153632-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153632-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 28.98,
#        'y': 47.85,
#        'width': 5.7,
#        'height': 26.3,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144006-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144006-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 32.51,
#        'y': 49.55,
#        'width': 9.5,
#        'height': 30.19,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155920-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155920-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 86.49,
#        'y': 39.94,
#        'width': 5.18,
#        'height': 7.67,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155838-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155838-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 62.41,
#        'y': 41.03,
#        'width': 10.08,
#        'height': 11.73,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 81.71,
#        'y': 35.31,
#        'width': 6.04,
#        'height': 11.81,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-142831-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-142831-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 83.49,
#        'y': 31.17,
#        'width': 5.24,
#        'height': 15.71,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153646-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153646-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 54.6,
#        'y': 49.68,
#        'width': 8.46,
#        'height': 36.89,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151618-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151618-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 59.22,
#        'y': 39.89,
#        'width': 4.72,
#        'height': 14.81,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155913-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155913-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 97.82,
#        'y': 36.36,
#        'width': 2.14,
#        'height': 12.34,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 86.31,
#        'y': 40.14,
#        'width': 4.96,
#        'height': 7.39,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143959-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143959-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 35.51,
#        'y': 43.1,
#        'width': 5.88,
#        'height': 22.28,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155104-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155104-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 89.03,
#        'y': 39.16,
#        'width': 4.72,
#        'height': 8.4,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155906-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155906-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 77.33,
#        'y': 35.43,
#        'width': 5.42,
#        'height': 12.09,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145713-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145713-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 44.76,
#        'y': 44.85,
#        'width': 7.05,
#        'height': 25.65,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143029-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143029-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 78.06,
#        'y': 31.9,
#        'width': 4.96,
#        'height': 15.22,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144719-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144719-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 38.88,
#        'y': 44.89,
#        'width': 5.94,
#        'height': 26.7,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151249-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151249-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 90.81,
#        'y': 34.17,
#        'width': 5.91,
#        'height': 13.51,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143903-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143903-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 38.3,
#        'y': 42.9,
#        'width': 7.14,
#        'height': 23.46,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155057-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155057-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 89.19,
#        'y': 37.22,
#        'width': 5.36,
#        'height': 10.71,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152118-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152118-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 79.04,
#        'y': 49.55,
#        'width': 12.84,
#        'height': 20.62,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144842-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144842-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 67.13,
#        'y': 37.87,
#        'width': 5.09,
#        'height': 12.34,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143924-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143924-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 49.85,
#        'y': 62.87,
#        'width': 14.25,
#        'height': 36.81,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153728-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153728-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 80.06,
#        'y': 40.26,
#        'width': 5.45,
#        'height': 7.55,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155639-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155639-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 64.34,
#        'y': 37.66,
#        'width': 4.99,
#        'height': 13.8,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 50.0,
#        'y': 46.1,
#        'width': 9.87,
#        'height': 25.65,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151831-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151831-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.12,
#        'y': 44.48,
#        'width': 7.08,
#        'height': 28.77,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145542-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145542-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 82.66,
#        'y': 35.75,
#        'width': 11.89,
#        'height': 12.42,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155721-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155721-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 77.27,
#        'y': 40.26,
#        'width': 5.18,
#        'height': 7.75,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155852-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155852-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 80.58,
#        'y': 34.5,
#        'width': 5.06,
#        'height': 13.07,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 65.01,
#        'y': 41.36,
#        'width': 10.2,
#        'height': 10.35,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143910-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143910-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 31.13,
#        'y': 50.49,
#        'width': 9.83,
#        'height': 33.36,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153742-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153742-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 91.79,
#        'y': 33.81,
#        'width': 5.88,
#        'height': 14.08,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-160913-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-160913-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 47.12,
#        'y': 40.1,
#        'width': 5.88,
#        'height': 22.2,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.8,
#        'y': 38.64,
#        'width': 5.7,
#        'height': 20.21,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-160906-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-160906-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 47.09,
#        'y': 40.06,
#        'width': 4.93,
#        'height': 22.36,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.77,
#        'y': 38.64,
#        'width': 5.61,
#        'height': 20.37,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143952-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143952-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 40.81,
#        'y': 42.21,
#        'width': 6.92,
#        'height': 21.92,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151345-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151345-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 88.02,
#        'y': 51.75,
#        'width': 11.92,
#        'height': 47.69,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155803-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155803-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 82.11,
#        'y': 39.89,
#        'width': 5.73,
#        'height': 7.43,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.68,
#        'y': 48.54,
#        'width': 9.62,
#        'height': 23.13,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152153-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152153-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 58.92,
#        'y': 36.53,
#        'width': 3.98,
#        'height': 18.67,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-160345-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-160345-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 59.31,
#        'y': 40.14,
#        'width': 4.81,
#        'height': 13.11,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.09,
#        'y': 48.21,
#        'width': 9.31,
#        'height': 26.01,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-150008-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-150008-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 56.56,
#        'y': 52.52,
#        'width': 14.12,
#        'height': 36.49,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153543-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153543-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 67.95,
#        'y': 36.93,
#        'width': 3.55,
#        'height': 13.31,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155023-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155023-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 56.0,
#        'y': 40.3,
#        'width': 6.1,
#        'height': 16.68,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144931-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144931-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 61.12,
#        'y': 52.96,
#        'width': 13.42,
#        'height': 45.5,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152303-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152303-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 64.58,
#        'y': 35.27,
#        'width': 4.53,
#        'height': 16.23,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-150447-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-150447-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 35.08,
#        'y': 45.13,
#        'width': 7.35,
#        'height': 24.63,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
# ...
#     'result': [{'value': {'rotation': 0,
#        'x': 31.86,
#        'y': 44.6,
#        'width': 6.65,
#        'height': 22.73,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145610-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145610-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 65.1,
#        'y': 38.51,
#        'width': 8.7,
#        'height': 13.23,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145624-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145624-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.28,
#        'y': 39.45,
#        'width': 5.94,
#        'height': 22.08,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145603-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145603-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 65.04,
#        'y': 39.16,
#        'width': 8.88,
#        'height': 12.62,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152146-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152146-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 62.01,
#        'y': 38.35,
#        'width': 4.17,
#        'height': 13.68,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-145549-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-145549-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 82.87,
#        'y': 34.9,
#        'width': 11.76,
#        'height': 13.15,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155927-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155927-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 86.52,
#        'y': 40.18,
#        'width': 5.09,
#        'height': 7.39,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-143842-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-143842-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 92.59,
#        'y': 33.73,
#        'width': 4.69,
#        'height': 14.08,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155625-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155625-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 66.54,
#        'y': 38.31,
#        'width': 5.21,
#        'height': 11.97,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 52.7,
#        'y': 48.34,
#        'width': 10.08,
#        'height': 24.31,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-152139-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-152139-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 93.6,
#        'y': 33.32,
#        'width': 4.2,
#        'height': 14.61,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-144924-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-144924-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 56.28,
#        'y': 42.98,
#        'width': 5.02,
#        'height': 26.79,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151625-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151625-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 79.01,
#        'y': 32.95,
#        'width': 5.64,
#        'height': 13.39,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151728-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151728-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 40.35,
#        'y': 42.21,
#        'width': 7.11,
#        'height': 21.63,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153700-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153700-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 46.42,
#        'y': 47.2,
#        'width': 9.9,
#        'height': 29.34,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153550-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153550-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.31,
#        'y': 39.0,
#        'width': 5.48,
#        'height': 20.29,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155544-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155544-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 59.37,
#        'y': 36.69,
#        'width': 3.65,
#        'height': 17.78,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 41.61,
#        'y': 42.57,
#        'width': 5.73,
#        'height': 21.67,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-151359-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-151359-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 86.95,
#        'y': 51.5,
#        'width': 13.02,
#        'height': 47.89,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153721-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153721-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 80.02,
#        'y': 40.34,
#        'width': 5.45,
#        'height': 7.43,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153639-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153639-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 35.14,
#        'y': 49.07,
#        'width': 9.87,
#        'height': 31.66,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155742-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155742-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 65.66,
#        'y': 43.63,
#        'width': 4.38,
#        'height': 8.04,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 82.14,
#        'y': 39.81,
#        'width': 5.39,
#        'height': 7.35,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-153557-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-153557-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 53.28,
#        'y': 39.04,
#        'width': 5.51,
#        'height': 20.21,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]},
#  {'data': {'filename': '130524-155845-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6',
#    'image': '/data/local-files/?d=FIMUS-3rd-hm12/images/130524-155845-hm12-awb1.5_1.5_br55_co0_ec0_iso640_3264x2464_sm3_ss79989_79989_fr6.jpg'},
#   'predictions': [{'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 62.59,
#        'y': 40.26,
#        'width': 9.8,
#        'height': 12.22,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]},
#    {'model_version': 'yolov9_1',
#     'result': [{'value': {'rotation': 0,
#        'x': 85.2,
#        'y': 33.69,
#        'width': 6.13,
#        'height': 13.51,
#        'rectanglelabels': ['Person']},
#       'id': 'result1',
#       'from_name': 'label',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'original_width': 3264,
#       'original_height': 2464,
#       'image_rotation': 0}]}]}]

# %%
import json
with open(f'{output_json}', 'w') as f:
    json.dump(res, f)
